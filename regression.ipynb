# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('data.csv')

# %%
data.describe()
# Out:
#        production_budget  worldwide_gross
# count       5.654000e+03     5.654000e+03
# mean        3.312836e+07     9.832537e+07
# std         4.219285e+07     1.848374e+08
# min         1.100000e+03     1.700000e+01
# 25%         6.000000e+06     7.010080e+06
# 50%         1.850000e+07     3.292634e+07
# 75%         4.000000e+07     1.038569e+08
# max         4.000000e+08     2.797801e+09

# %%
x = DataFrame(data, columns=['production_budget'])
y = DataFrame(data, columns=['worldwide_gross'])

# %%
plt.figure(figsize=(16,9))
plt.scatter(x, y, alpha=0.3, s=50)
plt.title("Movie Cost vs Global Revenue")
plt.xlabel("Production Budget $")
plt.ylabel("Worldwide Gross $")
plt.xlim(0, 425000000)
plt.ylim(0, 3000000000)
plt.show()

# %%
regression = LinearRegression()
regression.fit(x, y)
# Out:
# LinearRegression()

# %%
# theta_1
regression.coef_
# Out:
# array([[3.26365694]])

# %%
# intercept
regression.intercept_
# Out:
# array([-9794218.57488064])

# %%
plt.figure(figsize=(16,9))
plt.scatter(x, y, alpha=0.3, s=50)
plt.plot(x, regression.predict(x), color='red', linewidth=4)
plt.title("Movie Cost vs Global Revenue")
plt.xlabel("Production Budget $")
plt.ylabel("Worldwide Gross $")
plt.xlim(0, 425000000)
plt.ylim(0, 3000000000)
plt.show()

# %%
# R_squared (Goodness of fit)
regression.score(x, y)
# Out:
# 0.5550176786806847
